# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/sales_data.csv")

df.head()
# Out:
#    Order_ID  Order_Date   Product     Category Region  Quantity   Sales
# 0      1001  2026-01-05    Laptop  Electronics   West         2  120000
# 1      1002  2026-01-08     Mouse  Electronics  North         5    2500
# 2      1003  2026-01-10     Chair    Furniture  South         3   15000
# 3      1004  2026-02-12      Desk    Furniture   East         2   20000
# 4      1005  2026-02-15  Keyboard  Electronics   West         4    8000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_ID    15 non-null     int64
#  1   Order_Date  15 non-null     str
#  2   Product     15 non-null     str
#  3   Category    15 non-null     str
#  4   Region      15 non-null     str
#  5   Quantity    15 non-null     int64
#  6   Sales       15 non-null     int64
# dtypes: int64(3), str(4)
# memory usage: 972.0 bytes

# %%
df.describe()
# Out:
#           Order_ID   Quantity          Sales
# count    15.000000  15.000000      15.000000
# mean   1008.000000   3.466667   35700.000000
# std       4.472136   2.294922   33801.838496
# min    1001.000000   1.000000    2500.000000
# 25%    1004.500000   2.000000   13500.000000
# 50%    1008.000000   3.000000   20000.000000
# 75%    1011.500000   4.000000   52500.000000
# max    1015.000000  10.000000  120000.000000

# %%
df.isnull().sum()
# Out:
# Order_ID      0
# Order_Date    0
# Product       0
# Category      0
# Region        0
# Quantity      0
# Sales         0
# dtype: int64

# %%
total_sales = df["Sales"].sum()

print("Total Sales:", total_sales)
# Out:
# Total Sales: 535500

# %%
category_sales = df.groupby("Category")["Sales"].sum()

print(category_sales)
# Out:
# Category
# Electronics    297500
# Furniture      238000
# Name: Sales, dtype: int64

# %%
category_sales = df.groupby("Category")["Sales"].sum()

print(category_sales)
# Out:
# Category
# Electronics    297500
# Furniture      238000
# Name: Sales, dtype: int64

# %%
region_sales = df.groupby("Region")["Sales"].sum()

print(region_sales)
# Out:
# Region
# East     103000
# North    182500
# South     72000
# West     178000
# Name: Sales, dtype: int64

# %%
product_sales = df.groupby("Product")["Sales"].sum()

product_sales = product_sales.sort_values(ascending=False)

print(product_sales)
# Out:
# Product
# Laptop      180000
# Sofa        135000
# Monitor      90000
# Desk         50000
# Chair        35000
# Keyboard     20000
# Table        18000
# Mouse         7500
# Name: Sales, dtype: int64

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])

# %%
df["Month"] = df["Order_Date"].dt.to_period("M")

monthly_sales = df.groupby("Month")["Sales"].sum()

print(monthly_sales)
# Out:
# Month
# 2026-01    137500
# 2026-02     28000
# 2026-03     93000
# 2026-04     80000
# 2026-05     95000
# 2026-06     42000
# 2026-07     60000
# Freq: M, Name: Sales, dtype: int64

# %%
category_sales.plot(kind="bar")

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")

plt.show()

# %%
region_sales.plot(kind="bar")

plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")

plt.show()

# %%
product_sales.plot(kind="bar")

plt.title("Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales")

plt.xticks(rotation=45)

plt.show()

# %%
monthly_sales.plot(kind="line", marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.xticks(rotation=45)

plt.show()
